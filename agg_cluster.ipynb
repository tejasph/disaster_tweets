# %%
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
# https://towardsdatascience.com/a-friendly-introduction-to-text-clustering-fa996bcefd04 
# https://www.kaggle.com/tchainzzz/agglomerative-document-clustering-on-cord-19

# %%
df = pd.read_csv('data/vectorized_train.csv')

# %%
df.head()
# Out:
#    id         0         1         2         3         4         5         6  \
# 0   1 -0.278979  0.103926 -0.099896 -0.033250  0.006406 -0.127988  0.015576
# 1   4 -0.064835  0.060354 -0.166393 -0.344203  0.306547  0.060459  0.205219
# 2   5 -0.024668  0.059286 -0.071322 -0.074969  0.103867 -0.124814  0.033703
# 3   6 -0.167660  0.244378  0.077987 -0.135558 -0.028106 -0.211794 -0.039319
# 4   7 -0.068673  0.062337  0.030137  0.077085  0.084789  0.005437 -0.042100
#
#           7         8  ...       290       291       292       293       294  \
# 0  0.162036  0.019861  ... -0.308163  0.127427 -0.153923 -0.059484  0.200914
# 1 -0.072670 -0.099532  ... -0.063258  0.121803  0.005085 -0.031410  0.151826
# 2 -0.014304 -0.062268  ... -0.208227  0.020313  0.125149 -0.040904 -0.067651
# 3  0.010273  0.064539  ... -0.182993  0.181690  0.172492 -0.032437 -0.200355
# 4 -0.084338 -0.041983  ... -0.056272  0.148307  0.154113  0.114311  0.023254
#
#         295       296       297       298       299
# 0 -0.077234 -0.056179  0.045646 -0.063259 -0.056399
# 1  0.067330  0.063014 -0.075697 -0.233015  0.096144
# 2 -0.032820 -0.193037 -0.054479  0.056526  0.039146
# 3 -0.176960 -0.162615 -0.040300  0.026279 -0.030382
# 4 -0.064449 -0.169256 -0.071676 -0.166943  0.135751
#
# [5 rows x 301 columns]

# %%
agg = AgglomerativeClustering(affinity = 'cosine')
